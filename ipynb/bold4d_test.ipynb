# %%
import os
import nilearn as nil
from nilearn.image import new_img_like, load_img
from nilearn import image,plotting

import numpy as np

# %%
bold_list = os.listdir('./data/siam/train_bold')
b = load_img(os.path.join('./data/siam/train_bold/',bold_list[0]))
print(b.shape)
# Out:
# (49, 58, 47, 232)

# %%
first_rsn = image.index_img(b, 0)
plotting.plot_stat_map(first_rsn, threshold=1)

# %%
print(first_rsn)
print(first_rsn.shape)
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# data shape (49, 58, 47)
# affine:
# [[  -4.   -0.   -0.   96.]
#  [  -0.    4.   -0. -132.]
#  [   0.    0.    4.  -70.]
#  [   0.    0.    0.    1.]]
# metadata:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 48
# dim             : [ 3 49 58 47  1  1  1  1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.  4.  4.  4.  1.  1.  1.  1.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 46
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 14.228725
# cal_min         : -4.0745716
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : talairach
# sform_code      : talairach
# quatern_b       : -0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# qoffset_x       : 96.0
# qoffset_y       : -132.0
# qoffset_z       : -70.0
# srow_x          : [-4. -0. -0. 96.]
# srow_y          : [  -0.    4.   -0. -132.]
# srow_z          : [  0.   0.   4. -70.]
# intent_name     : b''
# magic           : b'n+1'
# (49, 58, 47)

# %%
# b_1 = b.get_data().reshape(-1)
# print(r_1.shape)
# r_1 = np.unique(r_1)
# r_1.sort()
# print(r_1)
